# %%
import pandas as pd 
import numpy as np 
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('owid-covid-data.csv')

# %%
df.head(n=10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 5      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 6      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# 7      AFG      Asia  Afghanistan  2020-01-10          NaN        0.0
# 8      AFG      Asia  Afghanistan  2020-01-11          NaN        0.0
# 9      AFG      Asia  Afghanistan  2020-01-12          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# ...

# %%
df['Country'].isnull().sum()
# Out:
# 0

# %%
df.tail(n=10)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 309678      ZWE    Africa  Zimbabwe  2023-05-01     264685.0        2.0
# 309679      ZWE    Africa  Zimbabwe  2023-05-02     264685.0        0.0
# 309680      ZWE    Africa  Zimbabwe  2023-05-03     264685.0        0.0
# 309681      ZWE    Africa  Zimbabwe  2023-05-04     264685.0        0.0
# 309682      ZWE    Africa  Zimbabwe  2023-05-05     264685.0        0.0
# 309683      ZWE    Africa  Zimbabwe  2023-05-06     264685.0        0.0
# 309684      ZWE    Africa  Zimbabwe  2023-05-07     264685.0        0.0
# 309685      ZWE    Africa  Zimbabwe  2023-05-08     264776.0       91.0
# 309686      ZWE    Africa  Zimbabwe  2023-05-09     264776.0        0.0
# 309687      ZWE    Africa  Zimbabwe  2023-05-10     264776.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 309678               6.571        5686.0         0.0                0.143
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.736270e+05  3.009060e+05        2.996420e+05  2.529760e+05
# mean   5.720062e+06  1.078888e+04        1.083173e+04  8.034578e+04
# std    3.574208e+07  1.033029e+05        1.005335e+05  4.152550e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    6.514500e+03  0.000000e+00        1.143000e+00  1.210000e+02
# 50%    6.209400e+04  1.700000e+01        3.828600e+01  1.225000e+03
# 75%    6.351960e+05  5.290000e+02        6.352502e+02  1.057925e+04
# max    7.659025e+08  7.460827e+06        6.410668e+06  6.927365e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  301000.000000        299770.000000            273627.000000
# mean       96.218953            96.588991             87308.498903
# std       602.347508           593.003157            137715.424666
# min         0.000000             0.000000                 0.000000
# ...

# %%
df = df.drop('new_cases_per_million', axis=1)

# %%
df = df.drop('total_cases_per_million', axis=1)

# %%
df.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df = df.rename(columns={'location': 'Country'})

# %%
df = df.rename(columns={'date': 'Date'})

# %%
 df = df.rename(columns={'continent': 'Continent'})

# %%
 df = df.rename(columns={'iso_code': 'ISO_code'})

# %%
df.head()
# Out:
#   ISO_code Continent      Country        Date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df['Continent'].describe()
# Out:
# count     294965
# unique         6
# top       Africa
# freq       69769
# Name: Continent, dtype: object

# %%
df
# Out:
#        ISO_code Continent      Country        Date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 309683      ZWE    Africa     Zimbabwe  2023-05-06     264685.0        0.0
# 309684      ZWE    Africa     Zimbabwe  2023-05-07     264685.0        0.0
# 309685      ZWE    Africa     Zimbabwe  2023-05-08     264776.0       91.0
# 309686      ZWE    Africa     Zimbabwe  2023-05-09     264776.0        0.0
# 309687      ZWE    Africa     Zimbabwe  2023-05-10     264776.0        0.0
#
# ...

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
df1=imputer.fit_transform(df['Continent'].values.reshape(-1, 1))

# %%
df['Continent']= imputer.transform(df1)

# %%
df['Continent'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#        ISO_code Continent      Country        Date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 309683      ZWE    Africa     Zimbabwe  2023-05-06     264685.0        0.0
# 309684      ZWE    Africa     Zimbabwe  2023-05-07     264685.0        0.0
# 309685      ZWE    Africa     Zimbabwe  2023-05-08     264776.0       91.0
# 309686      ZWE    Africa     Zimbabwe  2023-05-09     264776.0        0.0
# 309687      ZWE    Africa     Zimbabwe  2023-05-10     264776.0        0.0
#
# ...

# %%
df['Continent'].describe()
# Out:
# count     309688
# unique         6
# top       Africa
# freq       84492
# Name: Continent, dtype: object

# %%
df3 = df.groupby(['Date','Country',])[['Date','Country','total_cases','total_deaths','total_vaccinations']].sum().reset_index()
# Out:
# /var/folders/z_/qp8623510vndrxydtkwtx4r40000gn/T/ipykernel_4848/1942843448.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = df.groupby(['Date','Country',])[['Date','Country','total_cases','total_deaths','total_vaccinations']].sum().reset_index()

# %%
df3
# Out:
#               Date              Country  total_cases  total_deaths  \
# 0       2020-01-01            Argentina          0.0           0.0
# 1       2020-01-01               Mexico          0.0           0.0
# 2       2020-01-02            Argentina          0.0           0.0
# 3       2020-01-02               Mexico          0.0           0.0
# 4       2020-01-03          Afghanistan          0.0           0.0
# ...            ...                  ...          ...           ...
# 309683  2023-05-14               Serbia          0.0           0.0
# 309684  2023-05-14        South America          0.0           0.0
# 309685  2023-05-14  Upper middle income          0.0           0.0
# 309686  2023-05-14              Uruguay          0.0           0.0
# 309687  2023-05-14                World          0.0           0.0
#
#         total_vaccinations
# 0             0.000000e+00
# 1             0.000000e+00
# 2             0.000000e+00
# 3             0.000000e+00
# ...

# %% [markdown]
# يقوم ب انشاء داتا فريم جديده ويقوم ب وضع ناتج جمع المعلومات  الجداول ويقوم بترتيب البيانات حسب الفهرس

# %%
df
# Out:
#        ISO_code Continent      Country        Date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 309683      ZWE    Africa     Zimbabwe  2023-05-06     264685.0        0.0
# 309684      ZWE    Africa     Zimbabwe  2023-05-07     264685.0        0.0
# 309685      ZWE    Africa     Zimbabwe  2023-05-08     264776.0       91.0
# 309686      ZWE    Africa     Zimbabwe  2023-05-09     264776.0        0.0
# 309687      ZWE    Africa     Zimbabwe  2023-05-10     264776.0        0.0
#
# ...

# %%
df['total_cases'].dtypes
# Out:
# dtype('float64')

# %%
df['total_deaths'].dtypes
# Out:
# dtype('float64')

# %%
df['total_vaccinations'].dtypes
# Out:
# dtype('float64')

# %%
imputer = SimpleImputer(strategy='mean') 
df1=imputer.fit_transform(df['total_cases'].values.reshape(-1, 1))
df['total_cases']= imputer.transform(df1)

# %%
df['total_cases']
# Out:
# 0         5.720062e+06
# 1         5.720062e+06
# 2         5.720062e+06
# 3         5.720062e+06
# 4         5.720062e+06
#               ...
# 309683    2.646850e+05
# 309684    2.646850e+05
# 309685    2.647760e+05
# 309686    2.647760e+05
# 309687    2.647760e+05
# Name: total_cases, Length: 309688, dtype: float64

# %%
df['total_cases'].mean()
# Out:
# 5720061.700672814

# %%
imputer = SimpleImputer(strategy='mean') 
df1=imputer.fit_transform(df['total_deaths'].values.reshape(-1, 1))
df['total_deaths']= imputer.transform(df1)

# %%
df['total_deaths'].isnull().sum()
# Out:
# 0

# %%
df['total_deaths']
# Out:
# 0         80345.784031
# 1         80345.784031
# 2         80345.784031
# 3         80345.784031
# 4         80345.784031
#               ...
# 309683     5686.000000
# 309684     5686.000000
# 309685     5689.000000
# 309686     5689.000000
# 309687     5689.000000
# Name: total_deaths, Length: 309688, dtype: float64

# %%
df['total_deaths'].mean()
# Out:
# 80345.78403089619

# %%
imputer = SimpleImputer(strategy='mean') 
df1=imputer.fit_transform(df['total_vaccinations'].values.reshape(-1, 1))
df['total_vaccinations']= imputer.transform(df1)

# %%
df['total_vaccinations'].isnull().sum()
# Out:
# 0

# %%
df['total_vaccinations']
# Out:
# 0         3.765466e+08
# 1         3.765466e+08
# 2         3.765466e+08
# 3         3.765466e+08
# 4         3.765466e+08
#               ...
# 309683    3.765466e+08
# 309684    3.765466e+08
# 309685    3.765466e+08
# 309686    3.765466e+08
# 309687    3.765466e+08
# Name: total_vaccinations, Length: 309688, dtype: float64

# %%
df['total_vaccinations'].isnull().sum()
# Out:
# 0

# %%
df['total_vaccinations'].mean()
# Out:
# 376546624.8981278

# %%
df3
# Out:
#               Date              Country  total_cases  total_deaths  \
# 0       2020-01-01            Argentina          0.0           0.0
# 1       2020-01-01               Mexico          0.0           0.0
# 2       2020-01-02            Argentina          0.0           0.0
# 3       2020-01-02               Mexico          0.0           0.0
# 4       2020-01-03          Afghanistan          0.0           0.0
# ...            ...                  ...          ...           ...
# 309683  2023-05-14               Serbia          0.0           0.0
# 309684  2023-05-14        South America          0.0           0.0
# 309685  2023-05-14  Upper middle income          0.0           0.0
# 309686  2023-05-14              Uruguay          0.0           0.0
# 309687  2023-05-14                World          0.0           0.0
#
#         total_vaccinations
# 0             0.000000e+00
# 1             0.000000e+00
# 2             0.000000e+00
# 3             0.000000e+00
# ...

# %%
df4 =df3[df3['total_deaths'] >= 1000000]['Country']

# %%
df4.head()
# Out:
# 62922    World
# 63174    World
# 63426    World
# 63678    World
# 63930    World
# Name: Country, dtype: object

# %%
df5 =df3[df3['total_deaths'] > 1000000]['Country'].count()

# %%
df5
# Out:
# 6700

# %%
df.isnull().sum()
# Out:
# ISO_code                                        0
# Continent                                       0
# Country                                         0
# Date                                            0
# total_cases                                     0
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       299019
# excess_mortality_cumulative                299019
# excess_mortality                           299019
# excess_mortality_cumulative_per_million    299019
# Length: 65, dtype: int64
